# %% [markdown]
# # Problema 2: Fallos de producto

# %% [markdown]
# ## Realiza un AED sobre el conjunto de datos.

# %%
# TODO: AED general (nulos, target, outliers, correlaciones)

# %% [markdown]
# ### Texto para la captura
#
# - Título:
# - Qué hice y por qué:
# - Cómo lo comprobé:

# %% [markdown]
# ## Estadísticos iniciales.

# %%
# TODO: df.describe(include='all') + hallazgos

# %% [markdown]
# ### Texto para la captura
#
# - Título:
# - Qué hice y por qué:
# - Cómo lo comprobé:

# %% [markdown]
# ## Distribuciones de las variables numéricas del conjunto de datos.

# %%
# TODO: histogramas/boxplots con títulos y ejes

# %% [markdown]
# ### Texto para la captura
#
# - Título:
# - Qué hice y por qué:
# - Cómo lo comprobé:

# %% [markdown]
# ## Matriz de correlación.

# %%
# TODO: heatmap de correlación

# %% [markdown]
# ### Texto para la captura
#
# - Título:
# - Qué hice y por qué:
# - Cómo lo comprobé:

# %% [markdown]
# ## Realiza el preprocesamiento de datos de tu problema.

# %%
# TODO: plan de preprocesado (split, nulos, encoding, escalado, PCA)

# %% [markdown]
# ### Texto para la captura
#
# - Título:
# - Qué hice y por qué:
# - Cómo lo comprobé:

# %% [markdown]
# ## Reserva un conjunto de datos para validación y otro para testeo.

# %%
# TODO: train/valid/test solo con datos etiquetados

# %% [markdown]
# ### Texto para la captura
#
# - Título:
# - Qué hice y por qué:
# - Cómo lo comprobé:

# %% [markdown]
# ## Columnas inútiles, valores sin sentido y atípicos.

# %%
# TODO: criterios de limpieza en train (IDs, constantes, outliers)

# %% [markdown]
# ### Texto para la captura
#
# - Título:
# - Qué hice y por qué:
# - Cómo lo comprobé:

# %% [markdown]
# ## Tratamiento de valores nulos.

# %%
# TODO: imputación fit solo en train

# %% [markdown]
# ### Texto para la captura
#
# - Título:
# - Qué hice y por qué:
# - Cómo lo comprobé:

# %% [markdown]
# ## Análisis de variabilidad.

# %%
# TODO: eliminar varianza 0/casi 0

# %% [markdown]
# ### Texto para la captura
#
# - Título:
# - Qué hice y por qué:
# - Cómo lo comprobé:

# %% [markdown]
# ## Columnas categóricas.

# %%
# TODO: encoding categóricas (OneHotEncoder)

# %% [markdown]
# ### Texto para la captura
#
# - Título:
# - Qué hice y por qué:
# - Cómo lo comprobé:

# %% [markdown]
# ## Reducción de la dimensionalidad.

# %%
# TODO: PCA (fit solo en train)

# %% [markdown]
# ### Texto para la captura
#
# - Título:
# - Qué hice y por qué:
# - Cómo lo comprobé:

# %% [markdown]
# ## Realiza un etiquetado automático.

# %%
# TODO: LabelPropagation/LabelSpreading + umbral 0.90

# %% [markdown]
# ### Texto para la captura
#
# - Título:
# - Qué hice y por qué:
# - Cómo lo comprobé:

# %% [markdown]
# ## Entrena y optimiza distintos modelos supervisados.

# %% [markdown]
# ### Modelo 1.

# %%
# TODO: modelo supervisado 1 + optimización

# %% [markdown]
# ### Texto para la captura
#
# - Título:
# - Qué hice y por qué:
# - Cómo lo comprobé:

# %% [markdown]
# ### Modelo 2.

# %%
# TODO: modelo supervisado 2 + optimización

# %% [markdown]
# ### Texto para la captura
#
# - Título:
# - Qué hice y por qué:
# - Cómo lo comprobé:

# %% [markdown]
# ### Modelo 3.

# %%
# TODO: modelo supervisado 3 + optimización

# %% [markdown]
# ### Texto para la captura
#
# - Título:
# - Qué hice y por qué:
# - Cómo lo comprobé:

# %% [markdown]
# ## Crea un modelo ensemble y explica el criterio que utilizas.

# %%
# TODO: ensemble final + criterio

# %% [markdown]
# ### Texto para la captura
#
# - Título:
# - Qué hice y por qué:
# - Cómo lo comprobé:
